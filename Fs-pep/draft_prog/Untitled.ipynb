# %%
import parmed as pmd

# %%
pdb = pmd.load_file('../../Fs-pep/100-fs-peptide-400K.pdb')

# %%
pdb.topology
# Out:
# <Topology; 1 chains, 23 residues, 264 atoms, 263 bonds>

# %%
pdb.get_coordinates()[0]
# Out:
# array([[ 8.3450e+00, -1.2219e+01,  7.1060e+00],
#        [ 9.1280e+00, -1.1685e+01,  7.9340e+00],
#        [ 6.8780e+00, -1.2426e+01,  7.4200e+00],
#        [ 6.5700e+00, -1.1763e+01,  8.2290e+00],
#        [ 6.2730e+00, -1.2164e+01,  6.5520e+00],
#        [ 6.7570e+00, -1.3336e+01,  8.0090e+00],
#        [ 8.6740e+00, -1.2375e+01,  5.8000e+00],
#        [ 7.9510e+00, -1.2693e+01,  5.1710e+00],
#        [ 1.0015e+01, -1.2378e+01,  5.2990e+00],
#        [ 1.0442e+01, -1.3242e+01,  5.8070e+00],
#        [ 1.0033e+01, -1.2587e+01,  3.7390e+00],
#        [ 1.1061e+01, -1.2797e+01,  3.4410e+00],
#        [ 9.7960e+00, -1.1634e+01,  3.2650e+00],
#        [ 9.4150e+00, -1.3472e+01,  3.5900e+00],
#        [ 1.0799e+01, -1.1077e+01,  5.5770e+00],
#        [ 1.1970e+01, -1.1023e+01,  5.9290e+00],
#        [ 1.0114e+01, -9.9470e+00,  5.4400e+00],
#        [ 9.1800e+00, -1.0055e+01,  5.0720e+00],
#        [ 1.0664e+01, -8.5710e+00,  5.6360e+00],
#        [ 1.1529e+01, -8.6210e+00,  6.2980e+00],
# ...

# %%
import sys

# %%
sys.path.append('../')

# %%
from molecules.sim.openmm_simulation import openmm_simulate_amber_fs_pep

# %%
openmm_simulate_amber_fs_pep('../../Fs-pep/100-fs-peptide-400K.pdb', GPU_index=0, output_cm='test.h5')
